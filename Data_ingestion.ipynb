# %%
import pymongo 
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Shruti\\Downloads\\23. Financial_dataset.csv")

# %%
df.head()
# Out:
#     Age  Annual_Income  Monthly_Expenses  Savings_Rate  Debt_to_Income_Ratio  \
# 0  45.0      686081.81          17942.27          0.29                  0.25
# 1   NaN      796474.39          55385.20          0.12                  0.55
# 2  46.0      708707.11               NaN          0.29                  0.38
# 3  55.0      940641.40          55378.16          0.11                  0.18
# 4  38.0     1452826.39          74823.60          0.29                  0.75
#
#    Current_Investments_Value  Total_Loan_Amount  Avg_Credit_Score  \
# 0                 1807462.47          556913.97             651.0
# 1                 2935502.53          563982.05             728.0
# 2                 1569022.45          479932.78             748.0
# 3                 3154348.23          484769.37             686.0
# 4                 4180505.40          839038.16             593.0
#
#    Inflation_Rate  Interest_Rate  Years_of_Employment  Job_Stability_Score  \
# ...

# %%
data = df.to_dict("records")

# %%
url = "mongodb+srv://girijamuleypy:12345@cluster0.hxc9fov.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
url
# Out:
# 'mongodb+srv://girijamuleypy:12345@cluster0.hxc9fov.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %%
client = pymongo.MongoClient(url)

# %%
database = client["AIML"]

# %%
collection = database["Financials"]

# %%
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('688c611fe81be3768ab8f37d'), ObjectId('688c611fe81be3768ab8f37e'), ObjectId('688c611fe81be3768ab8f37f'), ObjectId('688c611fe81be3768ab8f380'), ObjectId('688c611fe81be3768ab8f381'), ObjectId('688c611fe81be3768ab8f382'), ObjectId('688c611fe81be3768ab8f383'), ObjectId('688c611fe81be3768ab8f384'), ObjectId('688c611fe81be3768ab8f385'), ObjectId('688c611fe81be3768ab8f386'), ObjectId('688c611fe81be3768ab8f387'), ObjectId('688c611fe81be3768ab8f388'), ObjectId('688c611fe81be3768ab8f389'), ObjectId('688c611fe81be3768ab8f38a'), ObjectId('688c611fe81be3768ab8f38b'), ObjectId('688c611fe81be3768ab8f38c'), ObjectId('688c611fe81be3768ab8f38d'), ObjectId('688c611fe81be3768ab8f38e'), ObjectId('688c611fe81be3768ab8f38f'), ObjectId('688c611fe81be3768ab8f390'), ObjectId('688c611fe81be3768ab8f391'), ObjectId('688c611fe81be3768ab8f392'), ObjectId('688c611fe81be3768ab8f393'), ObjectId('688c611fe81be3768ab8f394'), ObjectId('688c611fe81be3768ab8f395'), ObjectId('688c611fe81be3768ab8
# ...

# %%
cursor = collection.find()

# %%
list(cursor)
# Out:
# [{'_id': ObjectId('688b15bd58177d88febc5239'),
#   'Age': 45.0,
#   'Annual_Income': 686081.81,
#   'Monthly_Expenses': 17942.27,
#   'Savings_Rate': 0.29,
#   'Debt_to_Income_Ratio': 0.25,
#   'Current_Investments_Value': 1807462.47,
#   'Total_Loan_Amount': 556913.97,
#   'Avg_Credit_Score': 651.0,
#   'Inflation_Rate': 6.69,
#   'Interest_Rate': 6.65,
#   'Years_of_Employment': 9.4,
#   'Job_Stability_Score': 0.39,
#   'Emergency_Fund_Value': 67331.21,
#   'Retirement_Fund_Contribution': 98811.48,
#   'Customer_Segment': 'Bronze',
#   'Future_Balance': 2227592.16},
#  {'_id': ObjectId('688b15bd58177d88febc523a'),
#   'Age': nan,
#   'Annual_Income': 796474.39,
#   'Monthly_Expenses': 55385.2,
#   'Savings_Rate': 0.12,
#   'Debt_to_Income_Ratio': 0.55,
#   'Current_Investments_Value': 2935502.53,
#   'Total_Loan_Amount': 563982.05,
#   'Avg_Credit_Score': 728.0,
#   'Inflation_Rate': nan,
#   'Interest_Rate': 8.25,
#   'Years_of_Employment': 17.8,
#   'Job_Stability_Score': 0.5,
# ...

# %%
df = pd.DataFrame(list(cursor))

# %%
df.head()
# Out:
#                         _id   Age  Annual_Income  Monthly_Expenses  \
# 0  688b15bd58177d88febc5239  45.0      686081.81          17942.27
# 1  688b15bd58177d88febc523a   NaN      796474.39          55385.20
# 2  688b15bd58177d88febc523b  46.0      708707.11               NaN
# 3  688b15bd58177d88febc523c  55.0      940641.40          55378.16
# 4  688b15bd58177d88febc523d  38.0     1452826.39          74823.60
#
#    Savings_Rate  Debt_to_Income_Ratio  Current_Investments_Value  \
# 0          0.29                  0.25                 1807462.47
# 1          0.12                  0.55                 2935502.53
# 2          0.29                  0.38                 1569022.45
# 3          0.11                  0.18                 3154348.23
# 4          0.29                  0.75                 4180505.40
#
#    Total_Loan_Amount  Avg_Credit_Score  Inflation_Rate  Interest_Rate  \
# 0          556913.97             651.0            6.69           6.65
# ...

# %%
df.shape
# Out:
# (20000, 17)

# %%
df.to_csv("Financials.csv")
